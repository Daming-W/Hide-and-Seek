# %%
import tensorflow as tf
from tensorflow import keras
import cv2
import csv
import numpy as np
from tensorflow.keras import backend as K
from tensorflow.keras import layers
from tensorflow.keras import applications
from tensorflow.keras.models import Model, load_model
from matplotlib import pyplot as plt
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import SGD, Adam
import tensorflow_probability as tfp
tfd=tfp.distributions
tfpl=tfp.layers
from tensorflow import math
from tensorflow import random
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def read_data(path):

    #open path to read dataset.csv
    csvFile = open(path, "r")
    reader = csv.reader(csvFile)
    #assgin array to load two images and labels
    frame_0 = []
    frame_1 = []
    label = []

    for item in reader:   
    #read frames' path and labels
        frame_0_temp = item[0]
        frame_1_temp = item[1]
        label_temp = item[2]
        label_temp = float(label_temp)  
    #load frame through the frame path
        img0 = cv2.imread(frame_0_temp)
        img1 = cv2.imread(frame_1_temp)
    # use "append" to load images to array
        frame_0.append(img0)
        frame_1.append(img1)
        label.append(label_temp)
    #print('read data part: ',label)
    return frame_0, frame_1, label

def process_data(f0,f1,lab):

  #lab=keras.utils.to_categorical(lab, 1)
  f0 = np.asarray(f0)
  f1 = np.asarray(f1)
  lab = np.asarray(lab)
  #print(lab)
  return f0,f1,lab

# %%
training_path = '/content/drive/MyDrive/Daming Colab/Ranking/mix_train_data_set_20000.csv'
validation_path = '/content/drive/MyDrive/Daming Colab/Ranking/mix_train_data_set_10000.csv'

frame_0_train, frame_1_train, label_train = read_data(training_path)
frame_0_val, frame_1_val, label_val = read_data(validation_path)

frame_0_train, frame_1_train, label_train = process_data(frame_0_train, frame_1_train, label_train)
frame_0_val, frame_1_val, label_val = process_data(frame_0_val, frame_1_val, label_val)

print("finish loading DATA !")
# Out:
# finish loading DATA !

# %%
ResNet=tf.keras.applications.ResNet50(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000
    )

ResNet.summary()

# %%
x=ResNet.get_layer('avg_pool').output

m = layers.Dense(1)(x)   
#s = layers.Dense(1)(x) 

#mean = layers.Dropout(0.001)(m)
#log_sigma = layers.Dropout(0.001)(s)
'''
stdlayer=layers.Lambda(lambda x:
                tf.math.exp (tf.math.subtract (x,0.0)) )
std=stdlayer(s)
    
samplelayer=layers.Lambda(lambda x:
                  x[0]+tf.math.multiply(x[1],tf.random.normal(shape=[1], mean=0.0, stddev=1)))
sample=samplelayer([m,std])
'''
Base=Model(inputs=ResNet.input,outputs=m)

ResNet.trainable = False

#Base.layers[-5].trainable=True
#Base.layers[-4].trainable=True
#Base.layers[-3].trainable=True
#Base.layers[-2].trainable=True
Base.layers[-1].trainable=True

for layer in Base.layers:
    #print(layer.trainable)
    adam=keras.optimizers.Adam(0.0001)

Base.summary()
plot_model(Base, show_shapes=True, show_layer_names=True)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
def siamese():
  
    input_tensor = layers.Input(shape=(224, 224, 3))
    #base_model = Base()

    input_frame_0 = layers.Input(shape=(224, 224, 3))
    input_frame_1 = layers.Input(shape=(224, 224, 3))
    
    s0 = Base(input_frame_0)
    s1 = Base(input_frame_1)                  

    diff = keras.layers.Subtract()([s0,s1])  

    score = layers.Dense(1, activation='sigmoid')(diff)

    siamese_model = Model(inputs=[input_frame_0, input_frame_1], outputs=score)

    return siamese_model

siamese_model=siamese()
siamese_model.summary()
#plot_model(siamese_model, to_file='model.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# model (Functional)              (None, 1)            23589761    input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# subtract (Subtract)             (None, 1)            0           model[0][0]
#                                                                  model[1][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            2           subtract[0][0]
# ==================================================================================================
# Total params: 23,589,763
# Trainable params: 2,051
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
siamese_model.compile(keras.optimizers.SGD(learning_rate=5e-5),
                      loss=keras.losses.binary_crossentropy,
                      metrics=['accuracy'])

history=siamese_model.fit([frame_0_train, frame_1_train], label_train, 
                          epochs=30, batch_size=20, 
                          validation_data=([frame_0_val, frame_1_val], label_val), 
                          shuffle=True,
                          verbose=1)
# Out:
# Epoch 1/30
# 1000/1000 [==============================] - 136s 115ms/step - loss: 0.3709 - accuracy: 0.8357 - val_loss: 0.2409 - val_accuracy: 0.9117
# Epoch 2/30
# 1000/1000 [==============================] - 112s 112ms/step - loss: 0.2171 - accuracy: 0.9214 - val_loss: 0.2011 - val_accuracy: 0.9246
# Epoch 3/30
# 1000/1000 [==============================] - 111s 111ms/step - loss: 0.1905 - accuracy: 0.9287 - val_loss: 0.1839 - val_accuracy: 0.9297
# Epoch 4/30
# 1000/1000 [==============================] - 111s 111ms/step - loss: 0.1767 - accuracy: 0.9327 - val_loss: 0.1735 - val_accuracy: 0.9332
# Epoch 5/30
# 1000/1000 [==============================] - 112s 112ms/step - loss: 0.1677 - accuracy: 0.9354 - val_loss: 0.1663 - val_accuracy: 0.9347
# Epoch 6/30
# 1000/1000 [==============================] - 112s 112ms/step - loss: 0.1612 - accuracy: 0.9372 - val_loss: 0.1608 - val_accuracy: 0.9362
# Epoch 7/30
# 1000/1000 [==============================] - 112s 112ms/step - loss: 0.1561 - accuracy: 0.9388 - val_loss: 0.1565 - val_accuracy: 0.9372
# Epoch 8/30
# 1000/1000 [==============================] - 111s 112ms/step - loss: 0.1521 - accuracy: 0.9403 - val_loss: 0.1530 - val_accuracy: 0.9382
# Epoch 9/30
# 1000/1000 [==============================] - 111s 111ms/step - loss: 0.1487 - accuracy: 0.9416 - val_loss: 0.1500 - val_accuracy: 0.9393
# Epoch 10/30
# 1000/1000 [==============================] - 111s 111ms/step - loss: 0.1457 - accuracy: 0.9427 - val_loss: 0.1474 - val_accuracy: 0.9404
# Epoch 11/30
# 1000/1000 [==============================] - 111s 111ms/step - loss: 0.1432 - accuracy: 0.9433 - val_loss: 0.1451 - val_accuracy: 0.9413
# Epoch 12/30
# 1000/1000 [==============================] - 111s 111ms/step - loss: 0.1410 - accuracy: 0.9438 - val_loss: 0.1431 - val_accuracy: 0.9426
# Epoch 13/30
# 1000/1000 [==============================] - 111s 111ms/step - loss: 0.1390 - accuracy: 0.9448 - val_loss: 0.1413 - val_accuracy: 0.9431
# Epoch 14/30
# 1000/1000 [==============================] - 111s 111ms/step - loss: 0.1372 - accuracy: 0.9455 - val_loss: 0.1396 - val_accuracy: 0.9433
# Epoch 15/30
# 1000/1000 [==============================] - 111s 111ms/step - loss: 0.1355 - accuracy: 0.9463 - val_loss: 0.1381 - val_accuracy: 0.9437
# Epoch 16/30
# 1000/1000 [==============================] - 111s 111ms/step - loss: 0.1340 - accuracy: 0.9467 - val_loss: 0.1367 - val_accuracy: 0.9438
# Epoch 17/30
# 1000/1000 [==============================] - 111s 111ms/step - loss: 0.1326 - accuracy: 0.9470 - val_loss: 0.1354 - val_accuracy: 0.9440
# Epoch 18/30
# 1000/1000 [==============================] - 111s 111ms/step - loss: 0.1313 - accuracy: 0.9475 - val_loss: 0.1342 - val_accuracy: 0.9444
# Epoch 19/30
# 1000/1000 [==============================] - 111s 111ms/step - loss: 0.1301 - accuracy: 0.9480 - val_loss: 0.1331 - val_accuracy: 0.9446
# Epoch 20/30
# 1000/1000 [==============================] - 111s 111ms/step - loss: 0.1290 - accuracy: 0.9484 - val_loss: 0.1321 - val_accuracy: 0.9453
# Epoch 21/30
# 1000/1000 [==============================] - 111s 111ms/step - loss: 0.1279 - accuracy: 0.9489 - val_loss: 0.1311 - val_accuracy: 0.9458
# Epoch 22/30
# 1000/1000 [==============================] - 111s 111ms/step - loss: 0.1269 - accuracy: 0.9495 - val_loss: 0.1301 - val_accuracy: 0.9465
# Epoch 23/30
# 1000/1000 [==============================] - 111s 111ms/step - loss: 0.1259 - accuracy: 0.9500 - val_loss: 0.1292 - val_accuracy: 0.9465
# Epoch 24/30
# 1000/1000 [==============================] - 111s 111ms/step - loss: 0.1250 - accuracy: 0.9505 - val_loss: 0.1284 - val_accuracy: 0.9467
# Epoch 25/30
# 1000/1000 [==============================] - 111s 111ms/step - loss: 0.1241 - accuracy: 0.9506 - val_loss: 0.1276 - val_accuracy: 0.9472
# Epoch 26/30
# 1000/1000 [==============================] - 111s 111ms/step - loss: 0.1233 - accuracy: 0.9510 - val_loss: 0.1268 - val_accuracy: 0.9474
# Epoch 27/30
# 1000/1000 [==============================] - 111s 111ms/step - loss: 0.1225 - accuracy: 0.9515 - val_loss: 0.1261 - val_accuracy: 0.9474
# Epoch 28/30
# 1000/1000 [==============================] - 111s 111ms/step - loss: 0.1218 - accuracy: 0.9518 - val_loss: 0.1253 - val_accuracy: 0.9477
# Epoch 29/30
# 1000/1000 [==============================] - 111s 111ms/step - loss: 0.1210 - accuracy: 0.9520 - val_loss: 0.1247 - val_accuracy: 0.9481
# Epoch 30/30
# 1000/1000 [==============================] - 111s 111ms/step - loss: 0.1203 - accuracy: 0.9523 - val_loss: 0.1240 - val_accuracy: 0.9484

# %%
print(history.history.keys())
plt.subplot(221)
plt.plot(history.history["loss"])
plt.grid()
plt.title("train_loss")

plt.subplot(222)
plt.plot(history.history["accuracy"])
plt.grid()

plt.title("train_acc")
plt.show()

plt.subplot(221)
plt.plot(history.history["val_loss"])
plt.grid()
plt.title("test_loss")

plt.subplot(222)
plt.plot(history.history["val_accuracy"])
plt.grid()
plt.title("test_acc") 
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
Base.save('/content/drive/MyDrive/Daming Colab/Ranking/Model/DTR/_Drankingnet_ResNet2049_30eMD.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
